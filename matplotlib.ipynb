# %%
import pandas as pd
unemployment_data = pd.read_csv('C:/Users/maity/OneDrive/Desktop/Pworld/linearRegression/data.csv')

# %%
unemployment_data.head(10)
# Out:
#    Year Month  Primary_School    Date  High_School  Associates_Degree  \
# 0  2010   Jan            15.3  Jan-10         10.2                8.6
# 1  2011   Jan            14.3  Jan-11          9.5                8.1
# 2  2012   Jan            13.0  Jan-12          8.5                7.1
# 3  2013   Jan            12.0  Jan-13          8.1                6.9
# 4  2014   Jan             9.4  Jan-14          6.5                5.9
# 5  2015   Jan             8.3  Jan-15          5.4                5.2
# 6  2016   Jan             7.1  Jan-16          5.2                4.2
# 7  2017   Jan             7.4  Jan-17          5.2                3.8
# 8  2018   Jan             5.4  Jan-18          4.4                3.4
# 9  2019   Jan             5.7  Jan-19          3.7                3.4
#
#    Professional_Degree  White  Black  Asian  Hispanic   Men  Women
# 0                  4.9    8.8   16.5    8.3      12.9  10.2    7.9
# ...

# %%
unemployment_data.tail(40)
# Out:
#      Year Month  Primary_School    Date  High_School  Associates_Degree  \
# 88   2010   Sep            15.6  Sep-10          9.7                8.9
# 89   2011   Sep            14.3  Sep-11          9.4                8.5
# 90   2012   Sep            11.7  Sep-12          8.5                6.6
# 91   2013   Sep            10.5  Sep-13          7.6                6.1
# 92   2014   Sep             8.5  Sep-14          5.4                5.4
# 93   2015   Sep             7.9  Sep-15          5.3                4.3
# 94   2016   Sep             8.5  Sep-16          5.3                4.2
# 95   2017   Sep             6.7  Sep-17          4.4                3.6
# 96   2018   Sep             5.7  Sep-18          3.8                3.2
# 97   2019   Sep             4.8  Sep-19          3.6                2.9
# 99   2010   Oct            15.0  Oct-10          9.8                8.2
# 100  2011   Oct            13.5  Oct-11          9.4                8.1
# ...

# %%
unemployment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 132 non-null    int64
#  1   Month                132 non-null    object
#  2   Primary_School       123 non-null    float64
#  3   Date                 132 non-null    object
#  4   High_School          123 non-null    float64
#  5   Associates_Degree    123 non-null    float64
#  6   Professional_Degree  123 non-null    float64
#  7   White                123 non-null    float64
#  8   Black                123 non-null    float64
#  9   Asian                123 non-null    float64
#  10  Hispanic             123 non-null    float64
#  11  Men                  123 non-null    float64
#  12  Women                123 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 13.5+ KB

# %%
unemployment_data=unemployment_data.dropna()

# %%
unemployment_data.isna().sum()
# Out:
# Year                   0
# Month                  0
# Primary_School         0
# Date                   0
# High_School            0
# Associates_Degree      0
# Professional_Degree    0
# White                  0
# Black                  0
# Asian                  0
# Hispanic               0
# Men                    0
# Women                  0
# dtype: int64

# %%
unemployment_data.describe()
# Out:
#               Year  Primary_School  High_School  Associates_Degree  \
# count   123.000000      123.000000   123.000000         123.000000
# mean   2014.634146        9.329268     6.391057           5.338211
# std       2.973292        3.343178     2.223607           1.895314
# min    2010.000000        4.800000     3.400000           2.700000
# 25%    2012.000000        6.350000     4.450000           3.700000
# 50%    2015.000000        8.500000     5.500000           4.900000
# 75%    2017.000000       12.250000     8.300000           7.000000
# max    2020.000000       15.800000    11.000000           8.900000
#
#        Professional_Degree       White       Black       Asian    Hispanic  \
# count           123.000000  123.000000  123.000000  123.000000  123.000000
# mean              3.127642    5.455285   10.692683    4.679675    7.660163
# std               0.937585    1.881454    3.615907    1.668363    2.837274
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.plot('Date' , 'Associates_Degree' , data=unemployment_data, color='violet')
plt.plot('Date' , 'High_School' , data=unemployment_data, color='yellow')
plt.plot( 'Date', 'Professional_Degree', data=unemployment_data, color='blue')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.plot('Date' , 'White' , data=unemployment_data, color='magenta')
plt.plot('Date' , 'Black' , data=unemployment_data, color='yellow')
plt.plot('Date' , 'Asian' , data=unemployment_data, color='pink')
plt.plot('Date' , 'Hispanic' , data=unemployment_data, color='green')
plt.legend
# Out:
# C:\Users\maity\AppData\Local\Temp/ipykernel_3488/1513353115.py:2: RuntimeWarning: Second argument 'White' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('Date' , 'White' , data=unemployment_data, color='magenta')
# C:\Users\maity\AppData\Local\Temp/ipykernel_3488/1513353115.py:3: RuntimeWarning: Second argument 'Black' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot('Date' , 'Black' , data=unemployment_data, color='yellow')
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.figure(figsize=(10,10))
plt.plot( 'Date', 'Men', data=unemployment_data, color='blue')
plt.plot( 'Date', 'Women', data=unemployment_data, color='magenta')
plt.legend()

# %%
unemployment_data.head(50)
# Out:
#     Year Month  Primary_School    Date  High_School  Associates_Degree  \
# 0   2010   Jan            15.3  Jan-10         10.2                8.6
# 1   2011   Jan            14.3  Jan-11          9.5                8.1
# 2   2012   Jan            13.0  Jan-12          8.5                7.1
# 3   2013   Jan            12.0  Jan-13          8.1                6.9
# 4   2014   Jan             9.4  Jan-14          6.5                5.9
# 5   2015   Jan             8.3  Jan-15          5.4                5.2
# 6   2016   Jan             7.1  Jan-16          5.2                4.2
# 7   2017   Jan             7.4  Jan-17          5.2                3.8
# 8   2018   Jan             5.4  Jan-18          4.4                3.4
# 9   2019   Jan             5.7  Jan-19          3.7                3.4
# 10  2020   Jan             5.5  Jan-20          3.8                2.8
# 11  2010   Feb            15.8  Feb-10         10.7                8.1
# ...

# %%
unemployment_data.tail(50)
# Out:
#      Year Month  Primary_School    Date  High_School  Associates_Degree  \
# 77   2010   Aug            14.1  Aug-10         10.0                8.7
# 78   2011   Aug            14.1  Aug-11          9.3                8.3
# 79   2012   Aug            11.8  Aug-12          8.6                6.7
# 80   2013   Aug            11.1  Aug-13          7.4                6.1
# 81   2014   Aug             9.2  Aug-14          6.1                5.3
# 82   2015   Aug             7.9  Aug-15          5.5                4.3
# 83   2016   Aug             7.4  Aug-16          5.0                4.2
# 84   2017   Aug             6.1  Aug-17          5.1                3.7
# 85   2018   Aug             5.7  Aug-18          3.9                3.5
# 86   2019   Aug             5.4  Aug-19          3.6                3.0
# 88   2010   Sep            15.6  Sep-10          9.7                8.9
# 89   2011   Sep            14.3  Sep-11          9.4                8.5
# ...
